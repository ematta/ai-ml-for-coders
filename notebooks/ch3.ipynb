# %%
import tensorflow as tf
import keras as K

# %%
data = K.datasets.fashion_mnist

# %%
(training_images, training_labels), (test_images, test_labels) = data.load_data()

training_images = training_images / 255.0
test_images = test_images / 255.0

# %%
model = K.models.Sequential([
    K.layers.Conv2D(64, (3, 3), activation=tf.nn.relu, input_shape=(28, 28, 1)),
    K.layers.MaxPooling2D(2, 2),
    K.layers.Conv2D(64, (3, 3), activation=tf.nn.relu),
    K.layers.MaxPooling2D(2, 2),
    K.layers.Flatten(),
    K.layers.Dense(128, activation=tf.nn.relu),
    K.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(training_images, training_labels, epochs=50)
# Out:
# /Volumes/external/github.com/ematta/ai-ml-for-coders/venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.7834 - loss: 0.6074
# Epoch 2/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8869 - loss: 0.3018
# Epoch 3/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.9060 - loss: 0.2504
# Epoch 4/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9182 - loss: 0.2160
# Epoch 5/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9326 - loss: 0.1823
# Epoch 6/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.9419 - loss: 0.1563
# Epoch 7/50
# ...

# %%
model.evaluate(test_images, test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9074 - loss: 1.0381
# [0.9921573996543884, 0.9060999751091003]

# %%
classifications = model.predict(test_images)
print(classifications[0])
print(test_labels[0])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# [8.1262402e-34 1.9738312e-32 4.1767698e-31 6.1750452e-27 0.0000000e+00
#  3.9834336e-24 3.0030851e-37 7.1910583e-17 0.0000000e+00 1.0000000e+00]
# 9

# %%
import urllib.request
import zipfile

url = 'https://storage.googleapis.com/learning-datasets/horse-or-human.zip'
filename = 'horse-or-human.zip'
training_dir = 'horse-or-human/training'
urllib.request.urlretrieve(url, filename)
zip_ref = zipfile.ZipFile(filename, 'r')
zip_ref.extractall(training_dir)
zip_ref.close()

# %%
training_generator = K.utils.image_dataset_from_directory(
    training_dir,
    image_size=(300, 300),
    label_mode='binary',
)
# Out:
# Found 1027 files belonging to 2 classes.

# %%
model = K.models.Sequential([
    K.Input(shape=(300, 300, 3)),
    K.layers.Conv2D(16, (3, 3), activation=tf.nn.relu),
    K.layers.MaxPooling2D(2, 2),
    K.layers.Conv2D(32, (3, 3), activation=tf.nn.relu),
    K.layers.MaxPooling2D(2, 2),
    K.layers.Conv2D(64, (3, 3), activation=tf.nn.relu),
    K.layers.MaxPooling2D(2, 2),
    K.layers.Conv2D(64, (3, 3), activation=tf.nn.relu),
    K.layers.MaxPooling2D(2, 2),
    K.layers.Conv2D(64, (3, 3), activation=tf.nn.relu),
    K.layers.MaxPooling2D(2, 2),
    K.layers.Flatten(),
    K.layers.Dense(512, activation=tf.nn.relu),
    K.layers.Dense(1, activation=tf.nn.sigmoid)
])

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=K.optimizers.RMSprop(learning_rate=0.001),
    metrics=['accuracy']
)

# %%
history = model.fit(
    training_generator,
    epochs=15,
)
# Out:
# Epoch 1/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 251ms/step - accuracy: 0.6401 - loss: 78.0610
# Epoch 2/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 263ms/step - accuracy: 0.7503 - loss: 1.0824
# Epoch 3/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 256ms/step - accuracy: 0.7345 - loss: 1.6012
# Epoch 4/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 255ms/step - accuracy: 0.8620 - loss: 0.6853
# Epoch 5/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 256ms/step - accuracy: 0.8834 - loss: 0.7846
# Epoch 6/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 259ms/step - accuracy: 0.9380 - loss: 0.2420
# Epoch 7/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 256ms/step - accuracy: 0.9578 - loss: 0.7342
# Epoch 8/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 253ms/step - accuracy: 0.9750 - loss: 0.0592
# Epoch 9/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 250ms/step - accuracy: 0.9701 - loss: 0.3429
# Epoch 10/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 254ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 11/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 250ms/step - accuracy: 0.9035 - loss: 1.5440
# ...

# %%
validation_dir = 'horse-or-human/validation'
url = 'https://storage.googleapis.com/learning-datasets/validation-horse-or-human.zip'
urllib.request.urlretrieve(url, filename)
zip_ref = zipfile.ZipFile(filename, 'r')
zip_ref.extractall(validation_dir)
zip_ref.close()

# %%
validation_datagen = K.utils.image_dataset_from_directory(
    validation_dir,
    image_size=(300, 300),
    label_mode='binary',
)

model.evaluate(validation_datagen)
# Out:
# Found 256 files belonging to 2 classes.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.8488 - loss: 3.5249
# [2.5910861492156982, 0.87890625]

# %%
history = model.fit(
    training_generator,
    epochs=15,
    validation_data=validation_datagen,
)
# Out:
# Epoch 1/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step - accuracy: 1.0000 - loss: 1.1510e-06 - val_accuracy: 0.8789 - val_loss: 2.6703
# Epoch 2/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 267ms/step - accuracy: 1.0000 - loss: 5.1006e-07 - val_accuracy: 0.8828 - val_loss: 2.7564
# Epoch 3/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 268ms/step - accuracy: 1.0000 - loss: 3.9424e-07 - val_accuracy: 0.8867 - val_loss: 2.8790
# Epoch 4/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 273ms/step - accuracy: 1.0000 - loss: 5.9727e-07 - val_accuracy: 0.8789 - val_loss: 2.6021
# Epoch 5/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step - accuracy: 1.0000 - loss: 5.1268e-07 - val_accuracy: 0.8828 - val_loss: 2.7248
# Epoch 6/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 277ms/step - accuracy: 1.0000 - loss: 3.6564e-07 - val_accuracy: 0.8867 - val_loss: 2.7752
# Epoch 7/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step - accuracy: 1.0000 - loss: 1.4979e-07 - val_accuracy: 0.8867 - val_loss: 2.8132
# Epoch 8/15
# ...

# %%
from keras.api import layers, Model
from keras.api.applications.inception_v3 import InceptionV3
from keras.api.optimizers import RMSprop

# %%
weights_url = 'https://storage.googleapis.com/mledu-datasets/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'
weights_file = 'inception_v3.h5'
urllib.request.urlretrieve(weights_url, weights_file)
pretrained_model = InceptionV3(input_shape=(150, 150, 3), include_top=False, weights=None)
pretrained_model.load_weights(weights_file)
pretrained_model.summary()
# Out:
# Model: "inception_v3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 150, 150,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 74, 74,    │        864 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 74, 74,    │         96 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
for layer in pretrained_model.layers:
    layer.trainable = False

last_layer = pretrained_model.get_layer('mixed7')
shape = last_layer.compute_output_shape(input_shape=[(None, 150, 150, 3)])
print('last layer output shape:', shape)
last_output = last_layer.output
# Out:
# last layer output shape: (None, 150, 150, 3)

# %%
x = layers.Flatten()(last_output)
x = layers.Dense(1024, activation=tf.nn.relu)(x)
x = layers.Dense(1, activation=tf.nn.sigmoid)(x)

# %%
model = Model(pretrained_model.input, x)
model.compile(
    optimizer=RMSprop(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['acc']
)
